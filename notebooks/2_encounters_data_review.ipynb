# %%
import pandas as pd
from pathlib import Path

# %%
import sys

PROJECT_ROOT = Path.cwd()

if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from app.config.paths import find_root_project

root_dir = find_root_project()

data_dir = root_dir / "data"
raw_dir = data_dir / "raw"

encounters_file = raw_dir / "encounters.csv"

# %%
df_encounters_data = pd.read_csv(encounters_file)

# %%
df_encounters_data.head(10)
# Out:
#    encounter_id patient_id appointment_id encounter_type department_id  \
# 0  ENC000000001  PAT003523    APT00000001     Outpatient          D011
# 1  ENC000000002  PAT002899    APT00000002     Outpatient          D008
# 2  ENC000000003  PAT002528    APT00000003     Outpatient          D005
# 3  ENC000000004  PAT000790    APT00000004     Outpatient          D002
# 4  ENC000000005  PAT003052    APT00000005      Emergency          D003
# 5  ENC000000006  PAT000189    APT00000007     Outpatient          D005
# 6  ENC000000007  PAT001638    APT00000009      Follow-up          D012
# 7  ENC000000008  PAT002155    APT00000010     Outpatient          D005
# 8  ENC000000009  PAT003595    APT00000014      Emergency          D005
# 9  ENC000000010  PAT001920    APT00000016     Outpatient          D011
#
#   doctor_id encounter_date encounter_month                 chief_complaint  \
# 0   DOC0028     2022-06-02         2022-06                           Fever
# ...

# %%
df_encounters_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16642 entries, 0 to 16641
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   encounter_id      16642 non-null  str
#  1   patient_id        16642 non-null  str
#  2   appointment_id    12142 non-null  str
#  3   encounter_type    16642 non-null  str
#  4   department_id     16642 non-null  str
#  5   doctor_id         16642 non-null  str
#  6   encounter_date    16642 non-null  str
#  7   encounter_month   16642 non-null  str
#  8   chief_complaint   16642 non-null  str
#  9   diagnosis_code    16642 non-null  str
#  10  severity_level    16642 non-null  str
#  11  encounter_status  16642 non-null  str
# dtypes: str(12)
# memory usage: 3.1 MB

# %%
df_encounters_data["encounter_status"].unique()
# Out:
# <ArrowStringArray>
# ['Closed']
# Length: 1, dtype: str

# %% [markdown]
# đếm số thăm khám
